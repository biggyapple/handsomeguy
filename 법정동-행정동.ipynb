# %%
import pandas as pd
legal=pd.read_csv('C:/Users/user/.jupyter/법정동명.csv')
del legal['Unnamed: 0']
legal = legal.set_index('읍면동명',drop=False)
legal
# Out:
#       읍면동명
# 읍면동명
# 강정동    강정동
# 건입동    건입동
# 구좌읍    구좌읍
# 남원읍    남원읍
# 내도동    내도동
# ...    ...
# 호근동    호근동
# 화북이동  화북이동
# 화북일동  화북일동
# 회수동    회수동
# 회천동    회천동
#
# [73 rows x 1 columns]

# %%
#제주시
legal.loc[["이도이동","도남동"],"읍면동명"]="이도2동"
legal.loc[["일도일동"],"읍면동명"]="일도1동"
legal.loc[["일도이동"],"읍면동명"]="일도2동"
legal.loc[["이도일동"],"읍면동명"]="이도1동"
legal.loc[["삼도일동"],"읍면동명"]="삼도1동"
legal.loc[["삼도이동"],"읍면동명"]="삼도2동"
legal.loc[["용담일동"],"읍면동명"]="용담1동"
legal.loc[["용담이동","용담삼동"],"읍면동명"]="용담2동"
legal.loc[["화북일동","화북이동"],"읍면동명"]="화북동"
legal.loc[["삼양일동","삼양이동","삼양삼동","도련일동","도련이동"],"읍면동명"]="삼양동"
legal.loc[["봉개동","용강동","회천동"],"읍면동명"]="봉개동"
legal.loc[["아라일동","아라이동","오등동","월평동","영평동"],"읍면동명"]="아라동"
legal.loc[["해안동"],"읍면동명"]="노형동"
legal.loc[["외도일동","외도이동","도평동","내도동"],"읍면동명"]="외도동"
legal.loc[["이호일동","이호이동"],"읍면동명"]="이호동"
legal.loc[["도두일동","도두이동"],"읍면동명"]="도두동"
#서귀포시
legal.loc[["서귀동","동홍동","보목동","토평동"],"읍면동명"]="송산동"
legal.loc[["서귀동"],"읍면동명"]="정방동"
legal.loc[["서귀동"],"읍면동명"]="중앙동"
legal.loc[["서귀동","서홍동"],"읍면동명"]="천지동"
legal.loc[["하효동","신효동"],"읍면동명"]="효돈동"
legal.loc[["상효동","토평동"],"읍면동명"]="영천동"
legal.loc[["동홍동"],"읍면동명"]="동홍동"
legal.loc[["서홍동"],"읍면동명"]="서홍동"
legal.loc[["법환동","서호동","호근동"],"읍면동명"]="대륜동"
legal.loc[["월평동","강정동","도순동","영남동"],"읍면동명"]="대천동"
legal.loc[["중문동","회수동","대포동","하원동"],"읍면동명"]="중문동"
legal.loc[["색달동","상예동","하예동"],"읍면동명"]="예래동"


#legal.loc["서귀동", '이용금액'] = 

#sg=legal.loc["서귀동"]

#서귀동 4 동홍동 2 토평동2 서홍동2
# Out:
#      읍면동명
# 읍면동명
# 강정동   강정동
# 건입동   건입동
# 구좌읍   구좌읍
# 남원읍   남원읍
# 외도동   외도동
# ...   ...
# 호근동   호근동
# 화북동   화북동
# 화북동   화북동
# 회수동   회수동
# 봉개동   봉개동
#
# [73 rows x 1 columns]
